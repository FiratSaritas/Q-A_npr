# %%
import pandas as pd

df = pd.read_csv("qa.csv",encoding='latin-1',index_col="Id")
df.head()
# Out:
#        Topic  Difficulty (1-3)  \
# Id
# 1    history                 1
# 2     health                 3
# 3       tech                 3
# 4   offtopic                 1
# 5       news                 2
#
#                                                  Text  \
# Id
# 1   World War II or the Second World War, often ab...
# 2   Occupational therapy (OT) is a profession with...
# 3   In deep learning, each level learns to transfo...
# 4   The series focuses on Monkey D. Luffy, a young...
# 5   He told a news conference Mr Putin would pay a...
#
#                                            Question 1                Answer 1  \
# Id
# 1               When took the second World War place?            1939 to 1945
# 2   Occupational therapy is profession within whic...              healthcare
# 3                        What can a raw input may be?      a matrix of pixels
# 4                          On who focuses the series?         Monkey D. Ruffy
# 5                  What would Putin pay for invading?  serious and dear price
#
#                                            Question 2  \
# Id
# 1                    How many personnel was involved?
# 2                             By who is it performed?
# 3                         What does the second layer?
# 4                What is the name of the pirate crew?
# 5   Who warned that the comments could further des...
#
#                                              Answer 2  \
# Id
# 1                               more than 100 million
# 2   occupational therapists and occupational thera...
# 3                     compose and encode arrangements
# 4                                   Straw Hat Pirates
# 5                                         The Kremlin
#
#                                            Question 3  \
# Id
# 1                Who were the majority of fatalities?
# 2   What are common occupational therapy inerventi...
# 3                     What network are we speaking of
# 4                How is the mythical treasure called?
# 5             How many troops are near of the border?
#
#                                              Answer 3
# Id
# 1                                           civilians
# 2   helping children with disabilities, injury reh...
# 3                                                None
# 4                                           One Piece
# 5                                                 100

# %%
import csv
import json
 
csvFilePath = "/"
jsonFilePath = "/"

def csv_to_json(csvFilePath, jsonFilePath):
    jsonArray = []
      
    #read csv file
    with open(csvFilePath, encoding='latin-1') as csvf: 
        #load csv file data using csv library's dictionary reader
        csvReader = csv.DictReader(csvf) 

        #convert each csv row into python dict
        for row in csvReader: 
            #add this python dict to json array
            jsonArray.append(row)
  
    #convert python jsonArray to JSON String and write to file
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonString = json.dumps(jsonArray, indent=4)
        jsonf.write(jsonString)
          
csvFilePath = r'qa.csv'
jsonFilePath = r'qa.json'
csv_to_json(csvFilePath, jsonFilePath)
